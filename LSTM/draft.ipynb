# %%
with open('t1.txt',encoding='utf-8-sig') as file_object:
    contents = ""
    contents = file_object.read()
print(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-682ff84ee67a> in <module>()
# ----> 1 with open('t1.txt',encoding='utf-8-sig') as file_object:
#       2     contents = ""
#       3     contents = file_object.read()
#       4 print(contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: 't1.txt'

# %%
f = open('F:/50.xls', 'r')

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='F:/50.xls' mode='r' encoding='cp936'>

# %%
list[f]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-03606c2e921c> in <module>()
# ----> 1 list[f]
#
# TypeError: 'type' object is not subscriptable

# %%
f = open('F:/50.txt','r')

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='F:/50.txt' mode='r' encoding='cp936'>

# %%
import xlrd as xl

# %%
wb = xl.open_workbook(filename = 'F:/50.xls')
ws = wb.sheet_by_name('sheet1')
dataset = []
for i in range(ws.nrows):
    col = []
    for c in range(ws.ncols):
        col.append(ws.cell(r,c).value)
    dataset.append(col)
print(dataset)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-18-41f2b2c789a4> in <module>()
# ----> 1 wb = xl.open_workbook(filename = 'F:/50.xls')
#       2 ws = wb.sheet_by_name('sheet1')
#       3 dataset = []
#       4 for i in range(ws.nrows):
#       5     col = []
#
# C:\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     160         formatting_info=formatting_info,
#     161         on_demand=on_demand,
# --> 162         ragged_rows=ragged_rows,
#     163         )
#     164     return bk
#
# C:\Anaconda3\lib\site-packages\xlrd\book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      89         t1 = time.clock()
# ...

# %%
 f = open('F:/50.txt','r')
lines = []
lines = f.readlines()
f.close()
print(lines)
# Out:
# ['1.656E-08\n', '1.683E-08\n', '1.707E-08\n', '1.728E-08\n', '1.748E-08\n', '1.768E-08\n', '1.792E-08\n', '1.82E-08\n', '1.854E-08\n', '1.892E-08\n', '1.937E-08\n', '1.987E-08\n', '2.041E-08\n', '2.097E-08\n', '2.156E-08\n', '2.217E-08\n', '2.279E-08\n', '2.341E-08\n', '2.404E-08\n', '2.465E-08\n', '2.525E-08\n', '2.581E-08\n', '2.635E-08\n', '2.685E-08\n', '2.731E-08\n', '2.771E-08\n', '2.803E-08\n', '2.827E-08\n', '2.844E-08\n', '2.852E-08\n', '2.853E-08\n', '2.847E-08\n', '2.834E-08\n', '2.815E-08\n', '2.788E-08\n', '2.754E-08\n', '2.711E-08\n', '2.661E-08\n', '2.606E-08\n', '2.547E-08\n', '2.489E-08\n', '2.432E-08\n', '2.379E-08\n', '2.33E-08\n', '2.288E-08\n', '2.251E-08\n', '2.221E-08\n', '2.199E-08\n', '2.182E-08\n', '2.173E-08\n', '2.172E-08\n', '2.178E-08\n', '2.192E-08\n', '2.213E-08\n', '2.24E-08\n', '2.271E-08\n', '2.306E-08\n', '2.341E-08\n', '2.374E-08\n', '2.405E-08\n', '2.432E-08\n', '2.454E-08\n', '2.472E-08\n', '2.484E-08\n', '2.49E-08\n', '2.489E-08\n', '2.482E-08\
# ...

# %%
D = []

sum = 0
for i in range(2,30001):
    sum = sum + float(lines[i].replace("\n",""))
    aver = float(sum/i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-5b90235edadf> in <module>()
#       3 sum = 0
#       4 for i in range(2,30001):
# ----> 5     sum = sum + float(lines[i].replace("\n",""))
#       6     aver = float(sum/i)
#       7
#
# ValueError: could not convert string to float: 'Buffer1'

# %%
import pandas as pd

# %%
x = pd.read_csv('F:/50_2.csv') 
print(x)
# Out:
#          1.656E-08     8.65E-09  -1.412E-08  -58.5085
# 0        1.683E-08     8.98E-09  -1.424E-08  -57.7814
# 1        1.707E-08      9.3E-09  -1.431E-08   -56.978
# 2        1.728E-08     9.63E-09  -1.435E-08  -56.1459
# 3        1.748E-08     9.96E-09  -1.437E-08  -55.2782
# 4        1.768E-08     1.03E-08  -1.437E-08  -54.3616
# 5        1.792E-08    1.068E-08  -1.438E-08  -53.3921
# 6         1.82E-08    1.113E-08   -1.44E-08  -52.3187
# 7        1.854E-08    1.163E-08  -1.443E-08  -51.1408
# 8        1.892E-08    1.218E-08  -1.448E-08  -49.9309
# 9        1.937E-08    1.278E-08  -1.456E-08  -48.7261
# 10       1.987E-08    1.341E-08  -1.466E-08  -47.5494
# 11       2.041E-08    1.406E-08  -1.479E-08  -46.4487
# 12       2.097E-08    1.472E-08  -1.494E-08  -45.4284
# 13       2.156E-08    1.538E-08  -1.511E-08  -44.4921
# 14       2.217E-08    1.603E-08  -1.531E-08  -43.6753
# 15       2.279E-08    1.667E-08  -1.553E-08  -42.9713
# ...

# %%
print(list(x))
sum = 0
for i in range(1,5):
    sum = sum + int(lines[i])
print(sum)
# Out:
# ['1.656E-08', '8.65E-09', '-1.412E-08', '-58.5085']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-15be866cc918> in <module>()
#       2 sum = 0
#       3 for i in range(1,5):
# ----> 4     sum = sum + int(lines[i])
#       5 print(sum)
#
# ValueError: invalid literal for int() with base 10: '1.683E-08\n'

# %%
b = []
for i in range(1,30000)

# %%
float(lines[1].replace("\n",""))
# Out:
# 1.683e-08

# %%
p = lines.index('Buffer1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-793c4ab3094b> in <module>()
# ----> 1 p = lines.index('Buffer1')
#
# ValueError: 'Buffer1' is not in list

# %%
 f = open('F:/50.txt','r')
line = []
line = f.readlines()
f.close()
print(line)
D = []
# Out:
# ['1.66E-08\n', '1.68E-08\n', '1.71E-08\n', '1.73E-08\n', '1.75E-08\n', '1.77E-08\n', '1.79E-08\n', '1.82E-08\n', '1.85E-08\n', '1.89E-08\n', '1.94E-08\n', '1.99E-08\n', '2.04E-08\n', '2.10E-08\n', '2.16E-08\n', '2.22E-08\n', '2.28E-08\n', '2.34E-08\n', '2.40E-08\n', '2.47E-08\n', '2.53E-08\n', '2.58E-08\n', '2.64E-08\n', '2.69E-08\n', '2.73E-08\n', '2.77E-08\n', '2.80E-08\n', '2.83E-08\n', '2.84E-08\n', '2.85E-08\n', '2.85E-08\n', '2.85E-08\n', '2.83E-08\n', '2.82E-08\n', '2.79E-08\n', '2.75E-08\n', '2.71E-08\n', '2.66E-08\n', '2.61E-08\n', '2.55E-08\n', '2.49E-08\n', '2.43E-08\n', '2.38E-08\n', '2.33E-08\n', '2.29E-08\n', '2.25E-08\n', '2.22E-08\n', '2.20E-08\n', '2.18E-08\n', '2.17E-08\n', '2.17E-08\n', '2.18E-08\n', '2.19E-08\n', '2.21E-08\n', '2.24E-08\n', '2.27E-08\n', '2.31E-08\n', '2.34E-08\n', '2.37E-08\n', '2.41E-08\n', '2.43E-08\n', '2.45E-08\n', '2.47E-08\n', '2.48E-08\n', '2.49E-08\n', '2.49E-08\n', '2.48E-08\n', '2.47E-08\n', '2.45E-08\n', '2.43E-08\n', '2.41E-08\n', '2.
# ...

# %%
sum = 0
for i in range(2,30001):
    sum = sum + float(line[i].replace("\n",""))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-7b36d18aa104> in <module>()
#       1 sum = 0
#       2 for i in range(2,30001):
# ----> 3     sum = sum + float(line[i].replace("\n","").replace("Buffer1",""))
#
# ValueError: could not convert string to float:

# %%
print(len(line))
import re
# 去除\r\n\t字符
g = str(line)
s = g.replace('Buffer1', '')
print(s)
# Out:
# 30000
# ...

# %%
print(s.split(',',maxsplit=29998))
k = s.split(',',maxsplit=29998)
# Out:
# ["['1.66E-08\\n'", " '1.68E-08\\n'", " '1.71E-08\\n'", " '1.73E-08\\n'", " '1.75E-08\\n'", " '1.77E-08\\n'", " '1.79E-08\\n'", " '1.82E-08\\n'", " '1.85E-08\\n'", " '1.89E-08\\n'", " '1.94E-08\\n'", " '1.99E-08\\n'", " '2.04E-08\\n'", " '2.10E-08\\n'", " '2.16E-08\\n'", " '2.22E-08\\n'", " '2.28E-08\\n'", " '2.34E-08\\n'", " '2.40E-08\\n'", " '2.47E-08\\n'", " '2.53E-08\\n'", " '2.58E-08\\n'", " '2.64E-08\\n'", " '2.69E-08\\n'", " '2.73E-08\\n'", " '2.77E-08\\n'", " '2.80E-08\\n'", " '2.83E-08\\n'", " '2.84E-08\\n'", " '2.85E-08\\n'", " '2.85E-08\\n'", " '2.85E-08\\n'", " '2.83E-08\\n'", " '2.82E-08\\n'", " '2.79E-08\\n'", " '2.75E-08\\n'", " '2.71E-08\\n'", " '2.66E-08\\n'", " '2.61E-08\\n'", " '2.55E-08\\n'", " '2.49E-08\\n'", " '2.43E-08\\n'", " '2.38E-08\\n'", " '2.33E-08\\n'", " '2.29E-08\\n'", " '2.25E-08\\n'", " '2.22E-08\\n'", " '2.20E-08\\n'", " '2.18E-08\\n'", " '2.17E-08\\n'", " '2.17E-08\\n'", " '2.18E-08\\n'", " '2.19E-08\\n'", " '2.21E-08\\n'", " '2.24E-08\\n'", " '2.27
# ...

# %%
data = []
for i in range(1,29999):
    k[i].replace("\\n","").replace("'","")
    print(k[i].replace("\\n","").replace("'",""))
    data.append( k[i].replace("\\n","").replace("'",""))
print(data)
# Out:
#  1.68E-08
#  1.71E-08
#  1.73E-08
#  1.75E-08
#  1.77E-08
#  1.79E-08
#  1.82E-08
#  1.85E-08
#  1.89E-08
#  1.94E-08
#  1.99E-08
#  2.04E-08
#  2.10E-08
#  2.16E-08
#  2.22E-08
#  2.28E-08
#  2.34E-08
#  2.40E-08
#  2.47E-08
#  2.53E-08
#  2.58E-08
#  2.64E-08
#  2.69E-08
#  2.73E-08
#  2.77E-08
#  2.80E-08
#  2.83E-08
#  2.84E-08
#  2.85E-08
#  2.85E-08
#  2.85E-08
#  2.83E-08
#  2.82E-08
#  2.79E-08
#  2.75E-08
#  2.71E-08
#  2.66E-08
#  2.61E-08
#  2.55E-08
#  2.49E-08
#  2.43E-08
#  2.38E-08
#  2.33E-08
#  2.29E-08
#  2.25E-08
#  2.22E-08
#  2.20E-08
#  2.18E-08
#  2.17E-08
#  2.17E-08
#  2.18E-08
#  2.19E-08
#  2.21E-08
#  2.24E-08
#  2.27E-08
#  2.31E-08
#  2.34E-08
#  2.37E-08
#  2.41E-08
#  2.43E-08
#  2.45E-08
#  2.47E-08
#  2.48E-08
#  2.49E-08
#  2.49E-08
#  2.48E-08
#  2.47E-08
#  2.45E-08
#  2.43E-08
#  2.41E-08
#  2.38E-08
#  2.35E-08
#  2.32E-08
#  2.29E-08
#  2.26E-08
#  2.23E-08
#  0.000000022
#  2.17E-08
#  2.13E-08
#  2.09E-08
#  2.04E-08
#  2.00E-08
#  1.95E-08
# ...

# %%
float(data[1]) + 1
# Out:
# 1.0000000171

# %%
sd = 0
sum = 0
for i in range(1,29998):
    a = float(data[i])
    sum = sum + a
   
    v = sum/i
    d = a - v
    l = d*d
   
    sd = (sd + l)/i
print(sd)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-738843cc1fe5> in <module>()
#       2 sum = 0
#       3 for i in range(1,29998):
# ----> 4     a = float(data[i])
#       5     sum = sum + a
#       6
#
# ValueError: could not convert string to float:

# %%
fuck = 'g_abc_grg'
fuck1 = fuck.replace('abc','')
print(fuck1)
# Out:
# g__grg
