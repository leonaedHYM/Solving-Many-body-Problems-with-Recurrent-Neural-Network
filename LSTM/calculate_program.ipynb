# %%
 f = open('F:/50.txt','r')
line = []
line = f.readlines()
f.close()
print(len(line))
print(line)

D = 0
sum = 0
for i in range(1,2000):
    sum = sum + float(line[i].replace("\n",""))
    aver = sum/i
    l = float(line[i].replace("\n",""))-aver
    d = l*l
    D = D+d
N =  pow(D/2001,1/2)/pow(5/64,1/2)
print(sum)

print(D/2001)
print(N)
# Out:
# 29999
# ...
